# %%
import json
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
def auth_gss_client(path, scopes):
    credentials = ServiceAccountCredentials.from_json_keyfile_name(path,
                                                                   scopes)
    return gspread.authorize(credentials)

auth_json_path = '/Users/simonsu/.gcloud/auth_gspread.json'
gss_scopes = ['https://spreadsheets.google.com/feeds']
spread_key = '1CMl1Rm2Q1ZvHrl11XpGi7KRw3eLMEyrL3gXLolAMuYk'

gss_client = auth_gss_client(auth_json_path, gss_scopes)

# %%
print(open(auth_json_path).read())
# Out:
# {
#   "type": "service_account",
#   "project_id": "sibuzu-163203",
#   "private_key_id": "39a0c9785d37fc295f0bf6d97af0c19b23e83fd9",
# ...

# %%
ss = gss_client.open('File Station')

# %%
dir(gss_client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_ensure_xml_header',
#  'auth',
#  'create',
#  'del_spreadsheet',
#  'del_worksheet',
#  'get_cells_cell_id_feed',
#  'get_cells_feed',
#  'get_feed',
#  'get_spreadsheets_feed',
#  'get_worksheets_feed',
#  'import_csv',
#  'insert_permission',
#  'list_permissions',
#  'login',
#  'open',
#  'open_by_key',
#  'open_by_url',
#  'openall',
#  'post_cells',
#  'post_feed',
#  'put_feed',
#  'remove_permission',
#  'session']

# %%
# ref url: http://city.shaform.com/blog/2016/03/19/gspread.html
ss = gss_client.open_by_key(spread_key)

# %%
ss.worksheets()
# Out:
# [<Worksheet '工作表1' id:od6>]

# %%
ws = ss.worksheet('工作表1')

# %%
ws.col_values(1)
# Out:
# ['Function',
#  'Supports mounting a Cloud Drive (such as Google Drive, Dropbox, Microsoft OneDrive, Amazon Cloud Drive, Yandex Disk and Box).  ',
#  'Supports mounting remote shared folders through FTP or Microsoft networking (SMB/CIFS)',
#  'Supports opening documents via Office Online, Google Docs or Chrome Extension (Edit Office files in Google Docs, Sheets, and Slides)',
#  'Supports ISO Mounting (Up to 256 ISO Files)',
#  'Supports thumbnail display of multimedia files',
#  'Supports sharing download links and upload links',
#  'Supports sharing to other NAS users',
#  'Drag-n-drop Files via Chrome and Firefox Browsers',
#  'File Compression (ZIP or 7z)',
#  'Creation of and sending download links for sharing public files with expiration date and password protection',
#  'Mobile App: Qfile for file browsing and management',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(ws.get_all_records())

# %%
df
# Out:
#                                              Function Release  \
# 0   Supports mounting a Cloud Drive (such as Googl...      NO
# 1   Supports mounting remote shared folders throug...
# 2   Supports opening documents via Office Online, ...
# 3         Supports ISO Mounting (Up to 256 ISO Files)      NO
# 4      Supports thumbnail display of multimedia files     YES
# 5    Supports sharing download links and upload links     YES
# 6                 Supports sharing to other NAS users
# 7   Drag-n-drop Files via Chrome and Firefox Browsers     YES
# 8                        File Compression (ZIP or 7z)     YES
# 9   Creation of and sending download links for sha...     YES
# 10  Mobile App: Qfile for file browsing and manage...      NO
#
#                                               comment
# 0
# 1                                    can't understand
# 2        can't understand (Unable to reproduce in TS)
# 3
# 4                                  only support music
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
# Function    11 non-null object
# Release     11 non-null object
# comment     11 non-null object
# dtypes: object(3)
# memory usage: 344.0+ bytes

# %%
r = ws.get_all_records()
type(r)
# Out:
# list

# %%
type(r[0])
# Out:
# dict

# %%
r[0]
# Out:
# {'Function': 'Supports mounting a Cloud Drive (such as Google Drive, Dropbox, Microsoft OneDrive, Amazon Cloud Drive, Yandex Disk and Box).  ',
#  'Release': 'NO',
#  'comment': ''}
